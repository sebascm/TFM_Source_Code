# %%
# Importación de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.metrics import mean_squared_error, explained_variance_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Cálculo de Stock e Impacto económico**

# %% [markdown]
# Cargamos los ficheros de RMSE de modelos ML y Naives

# %%
file_path = "/content/drive/Othercomputers/Mi portátil/UOC/4o Semestre/TFM/Datos/best_rmse_by_product_final.csv"
RMSE_ML = pd.read_csv(file_path)

# %%
RMSE_ML
# Out:
#       producto       RMSE modelo
# 0            1  15.659334    XGB
# 1            1  14.895816     RF
# 2            1  15.594800    LGB
# 3            1  20.540469     DT
# 4            1  15.479945   LSTM
# ...        ...        ...    ...
# 4835      1000   2.985207   LSTM
# 4836      1000   2.974409     RF
# 4837      1000   2.979105    LGB
# 4838      1000   2.986006    XGB
# 4839      1000   2.981521     DT
#
# [4840 rows x 3 columns]

# %%
file_path = "/content/drive/Othercomputers/Mi portátil/UOC/4o Semestre/TFM/Datos/rmse_by_product_nb_final.csv"
RMSE_Naives = pd.read_csv(file_path)

# %%
RMSE_Naives
# Out:
#      producto       RMSE
# 0           1  34.217790
# 1           2  28.819255
# 2           3  23.303068
# 3           4  14.388258
# 4           5  13.575592
# ..        ...        ...
# 963       996   4.260733
# 964       997   3.877237
# 965       998   4.160251
# 966       999   6.268708
# 967      1000   4.301801
#
# [968 rows x 2 columns]

# %% [markdown]
# En primer lugar, vamos a quedarnos con el RMSE más bajo para cada producto (mejor modelo para cada producto)

# %%
# Encuentra el índice del menor RMSE por producto
indices_min_rmse = RMSE_ML.groupby('producto')['RMSE'].idxmin()

# Selecciona las filas correspondientes
best_rmse_by_ml = RMSE_ML.loc[indices_min_rmse]

# Muestra el DataFrame resultante
best_rmse_by_ml
# Out:
#       producto       RMSE modelo
# 1            1  14.895816     RF
# 9            2   9.958897    LGB
# 10           3   8.772048    LGB
# 19           4   9.368164    LGB
# 23           5   8.199181   LSTM
# ...        ...        ...    ...
# 4819       996   2.729071    LGB
# 4820       997   3.097152    LGB
# 4827       998   3.190243     DT
# 4834       999   4.453674     RF
# 4836      1000   2.974409     RF
#
# [968 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
best_rmse_by_ml.groupby('modelo').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Ahora vamos a importar el fichero del ciclo de aprovisionamiento

# %%
file_path = "/content/drive/Othercomputers/Mi portátil/UOC/4o Semestre/TFM/Datos/DatosCicloAprovisionamiento.xlsx"
DatosCicloAprovisionamiento = pd.read_excel(file_path)

# %%
DatosCicloAprovisionamiento['raiz_ciclo_aprovisionamiento'] = np.sqrt(DatosCicloAprovisionamiento['diasEntrePedidos'] + DatosCicloAprovisionamiento['diasLeadtime'])

# %%
DatosCicloAprovisionamiento
# Out:
#      producto  diasEntrePedidos  diasLeadtime  raiz_ciclo_aprovisionamiento
# 0           1                14            15                      5.385165
# 1           2                14            15                      5.385165
# 2           3                14            15                      5.385165
# 3           4                14            15                      5.385165
# 4           5                14            15                      5.385165
# ..        ...               ...           ...                           ...
# 995       996                14             2                      4.000000
# 996       997                14             2                      4.000000
# 997       998                16             4                      4.472136
# 998       999                 7             2                      3.000000
# 999      1000                14             2                      4.000000
#
# [1000 rows x 4 columns]

# %% [markdown]
# Ahora calculamos las udsStock

# %%
factor_servicio = 1.64
DatosCicloAprovisionamiento = DatosCicloAprovisionamiento.merge(best_rmse_by_ml, on='producto')
DatosCicloAprovisionamiento['udsStock'] = factor_servicio * DatosCicloAprovisionamiento['RMSE'] * DatosCicloAprovisionamiento['raiz_ciclo_aprovisionamiento']

# %%
DatosCicloAprovisionamiento
# Out:
#      producto  diasEntrePedidos  diasLeadtime  raiz_ciclo_aprovisionamiento  \
# 0           1                14            15                      5.385165
# 1           2                14            15                      5.385165
# 2           3                14            15                      5.385165
# 3           4                14            15                      5.385165
# 4           5                14            15                      5.385165
# ..        ...               ...           ...                           ...
# 963       996                14             2                      4.000000
# 964       997                14             2                      4.000000
# 965       998                16             4                      4.472136
# 966       999                 7             2                      3.000000
# 967      1000                14             2                      4.000000
#
#           RMSE modelo    udsStock
# 0    14.895816     RF  131.554933
# 1     9.958897    LGB   87.953698
# 2     8.772048    LGB   77.471837
# 3     9.368164    LGB   82.736538
# 4     8.199181   LSTM   72.412465
# ..         ...    ...         ...
# 963   2.729071    LGB   17.902707
# 964   3.097152    LGB   20.317320
# 965   3.190243     DT   23.398207
# 966   4.453674     RF   21.912078
# 967   2.974409     RF   19.512125
#
# [968 rows x 7 columns]

# %% [markdown]
# Importamos el fichero con los datos de precios

# %%
file_path = "/content/drive/Othercomputers/Mi portátil/UOC/4o Semestre/TFM/Datos/DatosPrecioMedio.xlsx"
DatosPrecioMedio = pd.read_excel(file_path)

# %%
DatosPrecioMedio
# Out:
#      producto  eurPrecioMedio
# 0           1       68.730000
# 1           2      148.330000
# 2           3      169.000000
# 3           4        0.604383
# 4           5        4.553314
# ..        ...             ...
# 995       996       17.120000
# 996       997       17.710000
# 997       998        8.270000
# 998       999        8.270000
# 999      1000       40.730000
#
# [1000 rows x 2 columns]

# %% [markdown]
# Calculamos el coste diario

# %%
DatosPrecioMedio = DatosPrecioMedio.merge(DatosCicloAprovisionamiento, on='producto')

# %%
factor = 0.05
DatosPrecioMedio['CosteStock'] = factor * DatosPrecioMedio['udsStock'] * DatosPrecioMedio['eurPrecioMedio']

# %%
DatosPrecioMedio
# Out:
#      producto  eurPrecioMedio  diasEntrePedidos  diasLeadtime  \
# 0           1       68.730000                14            15
# 1           2      148.330000                14            15
# 2           3      169.000000                14            15
# 3           4        0.604383                14            15
# 4           5        4.553314                14            15
# ..        ...             ...               ...           ...
# 963       996       17.120000                14             2
# 964       997       17.710000                14             2
# 965       998        8.270000                16             4
# 966       999        8.270000                 7             2
# 967      1000       40.730000                14             2
#
#      raiz_ciclo_aprovisionamiento       RMSE modelo    udsStock  CosteStock
# 0                        5.385165  14.895816     RF  131.554933  452.088527
# 1                        5.385165   9.958897    LGB   87.953698  652.308602
# 2                        5.385165   8.772048    LGB   77.471837  654.637019
# 3                        5.385165   9.368164    LGB   82.736538    2.500228
# 4                        5.385165   8.199181   LSTM   72.412465   16.485836
# ..                            ...        ...    ...         ...         ...
# 963                      4.000000   2.729071    LGB   17.902707   15.324717
# 964                      4.000000   3.097152    LGB   20.317320   17.990987
# 965                      4.472136   3.190243     DT   23.398207    9.675159
# 966                      3.000000   4.453674     RF   21.912078    9.060644
# 967                      4.000000   2.974409     RF   19.512125   39.736442
#
# [968 rows x 9 columns]

# %%
DatosPrecioMedio['CosteStock_365'] = 365 * DatosPrecioMedio['CosteStock']

# %%
DatosPrecioMedio
# Out:
#      producto  eurPrecioMedio  diasEntrePedidos  diasLeadtime  \
# 0           1       68.730000                14            15
# 1           2      148.330000                14            15
# 2           3      169.000000                14            15
# 3           4        0.604383                14            15
# 4           5        4.553314                14            15
# ..        ...             ...               ...           ...
# 963       996       17.120000                14             2
# 964       997       17.710000                14             2
# 965       998        8.270000                16             4
# 966       999        8.270000                 7             2
# 967      1000       40.730000                14             2
#
#      raiz_ciclo_aprovisionamiento       RMSE modelo    udsStock  CosteStock  \
# 0                        5.385165  14.895816     RF  131.554933  452.088527
# 1                        5.385165   9.958897    LGB   87.953698  652.308602
# 2                        5.385165   8.772048    LGB   77.471837  654.637019
# 3                        5.385165   9.368164    LGB   82.736538    2.500228
# 4                        5.385165   8.199181   LSTM   72.412465   16.485836
# ..                            ...        ...    ...         ...         ...
# 963                      4.000000   2.729071    LGB   17.902707   15.324717
# 964                      4.000000   3.097152    LGB   20.317320   17.990987
# 965                      4.472136   3.190243     DT   23.398207    9.675159
# 966                      3.000000   4.453674     RF   21.912078    9.060644
# 967                      4.000000   2.974409     RF   19.512125   39.736442
#
#      CosteStock_365
# 0     165012.312526
# 1     238092.639731
# 2     238942.511781
# 3        912.583086
# 4       6017.329970
# ..              ...
# 963     5593.521827
# 964     6566.710261
# 965     3531.432939
# 966     3307.135203
# 967    14503.801309
#
# [968 rows x 10 columns]

# %%
sumatorio_CosteStock_365 = DatosPrecioMedio['CosteStock_365'].sum()

# %%
sumatorio_CosteStock_365
# Out:
# 18691332.76752851

# %% [markdown]
# Ahora hacemos lo mismo para Naives

# %%
file_path = "/content/drive/Othercomputers/Mi portátil/UOC/4o Semestre/TFM/Datos/DatosCicloAprovisionamiento.xlsx"
DatosCicloAprovisionamiento = pd.read_excel(file_path)

# %%
DatosCicloAprovisionamiento['raiz_ciclo_aprovisionamiento'] = np.sqrt(DatosCicloAprovisionamiento['diasEntrePedidos'] + DatosCicloAprovisionamiento['diasLeadtime'])

# %%
factor_servicio = 1.64
DatosCicloAprovisionamiento = DatosCicloAprovisionamiento.merge(RMSE_Naives, on='producto')
DatosCicloAprovisionamiento['udsStock'] = factor_servicio * DatosCicloAprovisionamiento['RMSE'] * DatosCicloAprovisionamiento['raiz_ciclo_aprovisionamiento']

# %%
file_path = "/content/drive/Othercomputers/Mi portátil/UOC/4o Semestre/TFM/Datos/DatosPrecioMedio.xlsx"
DatosPrecioMedio = pd.read_excel(file_path)

# %%
DatosPrecioMedio = DatosPrecioMedio.merge(DatosCicloAprovisionamiento, on='producto')

# %%
factor = 0.05
DatosPrecioMedio['CosteStock'] = factor * DatosPrecioMedio['udsStock'] * DatosPrecioMedio['eurPrecioMedio']

# %%
DatosPrecioMedio['CosteStock_365'] = 365 * DatosPrecioMedio['CosteStock']

# %%
DatosPrecioMedio
# Out:
#      producto  eurPrecioMedio  diasEntrePedidos  diasLeadtime  \
# 0           1       68.730000                14            15
# 1           2      148.330000                14            15
# 2           3      169.000000                14            15
# 3           4        0.604383                14            15
# 4           5        4.553314                14            15
# ..        ...             ...               ...           ...
# 963       996       17.120000                14             2
# 964       997       17.710000                14             2
# 965       998        8.270000                16             4
# 966       999        8.270000                 7             2
# 967      1000       40.730000                14             2
#
#      raiz_ciclo_aprovisionamiento       RMSE    udsStock   CosteStock  \
# 0                        5.385165  34.217790  302.200238  1038.511117
# 1                        5.385165  28.819255  254.522157  1887.663575
# 2                        5.385165  23.303068  205.805011  1739.052343
# 3                        5.385165  14.388258  127.072354     3.840018
# 4                        5.385165  13.575592  119.895154    27.296016
# ..                            ...        ...         ...          ...
# 963                      4.000000   4.260733   27.950409    23.925550
# 964                      4.000000   3.877237   25.434675    22.522405
# 965                      4.472136   4.160251   30.512545    12.616937
# 966                      3.000000   6.268708   30.842045    12.753185
# 967                      4.000000   4.301801   28.219817    57.469656
#
#      CosteStock_365
# 0     379056.557871
# 1     688997.205002
# 2     634754.105350
# 3       1401.606635
# 4       9963.045805
# ..              ...
# 963     8732.825735
# 964     8220.677706
# 965     4605.182092
# 966     4654.912695
# 967    20976.424617
#
# [968 rows x 9 columns]

# %%
sumatorio_CosteStock_365 = DatosPrecioMedio['CosteStock_365'].sum()

# %%
sumatorio_CosteStock_365
# Out:
# 45412002.62008464
